# %% [markdown]
# ---
# title: Step 05 – Reporting
# subject: Churn Analysis
# subtitle: Step 05 – Reporting – Spotify Churn Analysis
# short_title: Reporting
# date: 2025-12-17
#
# authors:
#   - name: Jocelyn Perez
#     affiliations:
#       - name: University of California, Berkeley
#     email: jocelyneperez@berkeley.edu
#     orcid: 0000-0000-0000-0000
#
#   - name: Claire Kaoru Shimazaki
#     affiliations:
#       - name: University of California, Berkeley
#     email: ckshimazaki@berkeley.edu
#     orcid: 0000-0000-0000-0000
#
#   - name: Colby Zhang
#     affiliations:
#       - name: University of California, Berkeley
#     email: colbyzhang@berkeley.edu
#     orcid: 0000-0000-0000-0000
#
#   - name: Olorundamilola Kazeem
#     affiliations:
#       - name: University of California, Berkeley
#     email: dami@berkeley.edu
#     orcid: 0000-0003-2118-2221
#
# exports:
#   - format: pdf
#     # template: arxiv_two_column
#     output: ../pdf_builds/step05_main_ipynb_to.pdf
#     line_numbers: true
#
# license: BSD-3-Clause
#
# keywords: reporting, churn, spotify
#
# abstract:
#   Overall, complete, end-to-end write-up of the Spotify churn analysis,
#   summarizing data sources, methods, modeling decisions, results, and
#   reproducibility considerations.
# ---

# %% [markdown]
# # Step 05: Reporting

# %%
import src.step00_utils as step00_utils

# %%
step00_utils.DIR_PROJECT_CURRENT
# Out:
# PosixPath('/home/jovyan/Projects/STAT_159_259/final-group08/notebooks')

# %%
step00_utils.DIR_PROJECT_HOME
# Out:
# PosixPath('/home/jovyan/Projects/STAT_159_259/final-group08')

# %%
step00_utils.DIR_DATA
# Out:
# PosixPath('/home/jovyan/Projects/STAT_159_259/final-group08/data')

# %% [markdown]
# ## Spotify Churn Analysis and Inference

# %% [markdown]
# **Abstract** – A complete summary of your paper.
#
# **Related Work** – Discussion of other papers related to your own.
#
# **[Optional] Background** – Additional information needed to understand your work.
#
# **Methods/Approach** – A thorough description of what you did.
#
# **Evaluation/Analysis** – Discussion of your experiments and visualizations of your results.
#
# **Conclusions** – Summary of the key takeaways, as well as a discussion of limitations and areas for future work.

# %% [markdown]
# Q: What is the application domain or the field analysis/research?
# - A: Spotify Churn Analysis...

# %% [markdown]
# Q: What is the overarching goal of the project?
# - A: ...

# %% [markdown]
# Q: What is churn? Why are we interested in analyzing and infering churn? Why is this important or valuable?
# - A: Defnition of Churn
# - A: Reason for Interest in Analyzing and Inferening Churn
# - A: It is important to...

# %% [markdown]
# This is a link in Markdown: [Cockett, 2022](https://doi.org/10.5281/zenodo.6476040). Testing 1 2 3 ... [Prlic and Proctor, 2012](https://doi.org/10.1371/journal.pcbi.1002802).
